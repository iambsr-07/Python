# %%
# Find HCF or GCD of two numbers
# by using math library function by GCD function
import math
num1=45 # 3,5,9,15,45
num2=35 # 5,7,35
print (math.gcd(num1,num2))
# Out:
# 5

# %%
import math
print (math.gcd(34,23))
# Out:
# 1

# %%
import math
print (math.gcd(34, 24, 78, 90))
# Out:
# 2

# %%
# Find the GCD of two numbers bu using Euclidian method
def vsk_hcf (x,y): 
    while (y): 
        x,y = y,x%y 
        # x = y
        # y = x%y
        print ("x: ", x, " ", "y: ", y)
    return x

a=96
b=56
res = vsk_hcf(a,b) 
print ("GCD / HCF: ", res)
# Out:
# x:  56   y:  40
# x:  40   y:  16
# x:  16   y:  8
# x:  8   y:  0
# GCD / HCF:  8

# %%
# Find Least Common Multiple (LCM) of two numbers

def vsk_lcm(x,y): #user defined LCM function
    if (x>y): 
        large = x 
    else:
        large = y
    
    while (True):
        print ("Large: ", large," ", "x: ", x, " ", "y: ", y)
        if (large%x==0) and (large%y==0): 
            #when both condtions are true, loop will be terminate due to break
            lcm=large
            break
        large = large+1
    return lcm

a = int (input ("Enter the first number: "))
b = int (input ("Enter the second number: "))
res = vsk_lcm(a,b)
print ("LCM : ", res)
# Out:
# Enter the first number: 85
# Enter the second number: 65
# Large:  85   x:  85   y:  65
# Large:  86   x:  85   y:  65
# Large:  87   x:  85   y:  65
# Large:  88   x:  85   y:  65
# Large:  89   x:  85   y:  65
# Large:  90   x:  85   y:  65
# Large:  91   x:  85   y:  65
# Large:  92   x:  85   y:  65
# Large:  93   x:  85   y:  65
# Large:  94   x:  85   y:  65
# Large:  95   x:  85   y:  65
# Large:  96   x:  85   y:  65
# Large:  97   x:  85   y:  65
# Large:  98   x:  85   y:  65
# Large:  99   x:  85   y:  65
# Large:  100   x:  85   y:  65
# Large:  101   x:  85   y:  65
# Large:  102   x:  85   y:  65
# Large:  103   x:  85   y:  65
# Large:  104   x:  85   y:  65
# Large:  105   x:  85   y:  65
# Large:  106   x:  85   y:  65
# Large:  107   x:  85   y:  65
# Large:  108   x:  85   y:  65
# Large:  109   x:  85   y:  65
# Large:  110   x:  85   y:  65
# Large:  111   x:  85   y:  65
# Large:  112   x:  85   y:  65
# Large:  113   x:  85   y:  65
# ...

# %%
print (2 ** 45)
# Out:
# 35184372088832

# %%
print(:bharat)
