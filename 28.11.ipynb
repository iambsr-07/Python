# %%
# program to comvert celsius to farehneit and vice versa ==>
"""op=(input("enter c for changing temerature to celsius and f for changing to farenheit ====>"))
if op =="c":
    c=float(input("enter your temperature in farehneit ==>"))
    f = ((9* c/5)+32)
    print(f)
else :
    if op=="f":
        f=float(input("enter your temperature in celsius ==>"))
        c = ((f -32) * (5/9))
        print(c)
print("galat dala hai shi kar")



# use while loop tp add up all  numbers  between 100 and 200
sum=0
n=100
while n>=100 and n<=200 :
    if n%2==0:
        sum=sum+n
        n=n+1
    else:
        n=n+1
print(sum)


#fibonacci series code  ===>
nths=int(input("enter two number  :"))
n1,n2=0,1
count=0
if nths<=0:
    print("please enter positive  number :")
elif nths==1:
    print("Fibonacci sequence upto",nths,":")
    print(n1)
else:
    print("fibonacci sequence:")
    while count < nths:
        print(n1)
        nth=n1+n2
        n1=n2
        n2=nth
        count+=1

    

# palindrome  
num  =int(input("enter an number::"))
temp=num
rev=0
while(num>0):
    dig=num%10
    rev=rev*10+dig
    num=num/10
if(temp==rev):
    print("number is palindrome")
else:
    print("number is not palindrome")
# palindrome code  for string

name="bhahb"
revs=[::-1]
print(revs)
if name== revs:
    print("palindrome string")
else:
    print("not palindrome")


for x in "banana":
    print(x)

numbers=[6,5,3,8,4,2,5,4,11]
sum=0
for val in numbers:
    sum=sum+val
print("the sum is",sum)


print(range(10))
print(list(range(10)))
"""
digit=[0,1,5]
for i in digit:
    print(i)
else:
    print("no itrm left ")
print(list(range(2,8)))
